# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    database="socialapp",
    user="manojtungala"
)

cursor = conn.cursor()

table_name = "users"

cursor.execute(f"""
SELECT
    tc.table_name,
    kcu.column_name
FROM information_schema.table_constraints tc
JOIN information_schema.key_column_usage kcu
ON tc.constraint_name = kcu.constraint_name
WHERE tc.constraint_type = 'PRIMARY KEY';
""")

schema = cursor.fetchall()

for col in schema:
    print(col)

conn.close()
# Out:
# ('userid', 'character varying', 'NO')
# ('username', 'character varying', 'NO')
# ('email', 'character varying', 'NO')
# ('password', 'character varying', 'NO')
# ('fullname', 'character varying', 'YES')
# ('bio', 'text', 'YES')
# ('profpicurl', 'text', 'YES')
# ('createdat', 'timestamp without time zone', 'YES')

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    database="socialapp",
    user="manojtungala"
)

cursor = conn.cursor()

with open("/Users/manojtungala/Desktop/project_work/rest-apis/database/socialapp.sql","r") as file:
    sql_script = file.read()

cursor.execute(sql_script)

conn.commit()

print("SQL script executed successfully")

cursor.close()
conn.close()
# Out:
# SQL script executed successfully
